# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("merged_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  index       Num_Acc        date  hour  minute  \
# 0           0      1  201600000001  2016-01-02    14      45
# 1           1      4  201600000002  2016-03-16    18       0
# 2           2      6  201600000003  2016-07-13    19       0
# 3           3      7  201600000004  2016-08-15    19      30
# 4           4     11  201600000005  2016-12-23    11       0
#
#            lighting         intersection        atmosphere    collision  ...  \
# 0          Full day  Out of intersection    Cloudy weather  By the side  ...
# 1          Full day             Giratory            Normal        Other  ...
# 2          Full day  Out of intersection            Normal        Other  ...
# 3  Twilight or dawn  Out of intersection  Dazzling weather  By the side  ...
# 4          Full day       T Intersection            Normal  By the side  ...
#
#   user_sex                  pedestrian_action vehicle_ID      road_category  \
# ...
